# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from IPython.display import display
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
who = pd.read_csv('Life Expectancy Data.csv') #2000/2015
who.head(17)
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 0   Afghanistan  2015  Developing              65.0            263.0
# 1   Afghanistan  2014  Developing              59.9            271.0
# 2   Afghanistan  2013  Developing              59.9            268.0
# 3   Afghanistan  2012  Developing              59.5            272.0
# 4   Afghanistan  2011  Developing              59.2            275.0
# 5   Afghanistan  2010  Developing              58.8            279.0
# 6   Afghanistan  2009  Developing              58.6            281.0
# 7   Afghanistan  2008  Developing              58.1            287.0
# 8   Afghanistan  2007  Developing              57.5            295.0
# 9   Afghanistan  2006  Developing              57.3            295.0
# 10  Afghanistan  2005  Developing              57.3            291.0
# 11  Afghanistan  2004  Developing              57.0            293.0
# 12  Afghanistan  2003  Developing              56.7            295.0
# 13  Afghanistan  2002  Developing              56.2              3.0
# 14  Afghanistan  2001  Developing              55.3            316.0
# 15  Afghanistan  2000  Developing              54.8            321.0
# 16      Albania  2015  Developing              77.8             74.0
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0              62     0.01               71.279624         65.0      1154
# 1              64     0.01               73.523582         62.0       492
# 2              66     0.01               73.219243         64.0       430
# 3              69     0.01               78.184215         67.0      2787
# 4              71     0.01                7.097109         68.0      3013
# 5              74     0.01               79.679367         66.0      1989
# 6              77     0.01               56.762217         63.0      2861
# 7              80     0.03               25.873925         64.0      1599
# 8              82     0.02               10.910156         63.0      1141
# 9              84     0.03               17.171518         64.0      1990
# 10             85     0.02                1.388648         66.0      1296
# 11             87     0.02               15.296066         67.0       466
# 12             87     0.01               11.089053         65.0       798
# 13             88     0.01               16.887351         64.0      2486
# 14             88     0.01               10.574728         63.0      8762
# 15             88     0.01               10.424960         62.0      6532
# 16              0     4.60              364.975229         99.0         0
#
#      BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# 0    19.1                  83    6.0               8.16         65.0
# 1    18.6                  86   58.0               8.18         62.0
# 2    18.1                  89   62.0               8.13         64.0
# 3    17.6                  93   67.0               8.52         67.0
# 4    17.2                  97   68.0               7.87         68.0
# 5    16.7                 102   66.0               9.20         66.0
# 6    16.2                 106   63.0               9.42         63.0
# 7    15.7                 110   64.0               8.33         64.0
# 8    15.2                 113   63.0               6.73         63.0
# 9    14.7                 116   58.0               7.43         58.0
# 10   14.2                 118   58.0               8.70         58.0
# 11   13.8                 120    5.0               8.79          5.0
# 12   13.4                 122   41.0               8.82         41.0
# 13   13.0                 122   36.0               7.76         36.0
# 14   12.6                 122   35.0               7.80         33.0
# 15   12.2                 122   24.0               8.20         24.0
# 16   58.0                   0   99.0               6.00         99.0
#
#      HIV/AIDS          GDP  Population   thinness  1-19 years  \
# 0         0.1   584.259210  33736494.0                   17.2
# 1         0.1   612.696514    327582.0                   17.5
# 2         0.1   631.744976  31731688.0                   17.7
# 3         0.1   669.959000   3696958.0                   17.9
# 4         0.1    63.537231   2978599.0                   18.2
# 5         0.1   553.328940   2883167.0                   18.4
# 6         0.1   445.893298    284331.0                   18.6
# 7         0.1   373.361116   2729431.0                   18.8
# 8         0.1   369.835796  26616792.0                   19.0
# 9         0.1   272.563770   2589345.0                   19.2
# 10        0.1    25.294130    257798.0                   19.3
# 11        0.1   219.141353  24118979.0                   19.5
# 12        0.1   198.728544   2364851.0                   19.7
# 13        0.1   187.845950  21979923.0                   19.9
# 14        0.1   117.496980   2966463.0                    2.1
# 15        0.1   114.560000    293756.0                    2.3
# 16        0.1  3954.227830     28873.0                    1.2
#
#      thinness 5-9 years  Income composition of resources  Schooling
# 0                  17.3                            0.479       10.1
# 1                  17.5                            0.476       10.0
# 2                  17.7                            0.470        9.9
# 3                  18.0                            0.463        9.8
# 4                  18.2                            0.454        9.5
# 5                  18.4                            0.448        9.2
# 6                  18.7                            0.434        8.9
# 7                  18.9                            0.433        8.7
# 8                  19.1                            0.415        8.4
# 9                  19.3                            0.405        8.1
# 10                 19.5                            0.396        7.9
# 11                 19.7                            0.381        6.8
# 12                 19.9                            0.373        6.5
# 13                  2.2                            0.341        6.2
# 14                  2.4                            0.340        5.9
# 15                  2.5                            0.338        5.5
# 16                  1.3                            0.762       14.2

# %%
#who.loc[who[' BMI ']<5, 'Country']

# %% [markdown]
# ### who.columns

# %%
#there are spaces in column names, gets tricky when I want to call them. rename them:
who.rename(columns={'Life expectancy ':'Life expectancy', 'Measles ':'Measles', ' BMI ':'BMI',
                    'under-five deaths ':'under-five deaths', 'Diphtheria ':'Diphtheria',
                    ' HIV/AIDS':'HIV/AIDS', ' thinness  1-19 years':'thinness  1-19 years',
                    ' thinness 5-9 years':'thinness 5-9 years','percentage expenditure':'% health financing',
                    'Total expenditure':'Total health financing'}, inplace=True)

# %%
who.shape #(2938, 22) #life expectancy is the target. 20 predictors (drop countries? population?)
who.dtypes #everything is already in ordinal except for Status (categorical)
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# % health financing                 float64
# Hepatitis B                        float64
# Measles                              int64
# BMI                                float64
# under-five deaths                    int64
# Polio                              float64
# Total health financing             float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# Population                         float64
# thinness  1-19 years               float64
# thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
who.Status.value_counts() #looks great, only 2 categories (get_dummies)
# Out:
# Developing    2426
# Developed      512
# Name: Status, dtype: int64

# %%
who.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', '% health financing', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio',
#        'Total health financing', 'Diphtheria', 'HIV/AIDS', 'GDP', 'Population',
#        'thinness  1-19 years', 'thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
print(who['BMI'].min(), who['BMI'].max())
print(who['Income composition of resources'].min(), who['Income composition of resources'].max()) #percentager
# Out:
# 1.0 87.3
# 0.0 0.948

# %%
#deal with missing values
who.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# % health financing                   0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total health financing             226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
print('Proportions of missing values in:')
print(f"Alcohol {round((194/2938)*100, 2)}%")
print(f"Hepatitis B {round((553/2938)*100, 2)}%")
print(f"Total health financing {round((226/2938)*100, 2)}%")
print(f"GDP {round((448/2938)*100, 2)}%")
print(f"Population {round((652/2938)*100, 2)}%")
print(f"Income composition of resources {round((167/2938)*100, 2)}%")
print(f"Schooling {round((163/2938)*100, 2)}%")
# Out:
# Proportions of missing values in:
# Alcohol 6.6%
# Hepatitis B 18.82%
# Total health financing 7.69%
# GDP 15.25%
# Population 22.19%
# Income composition of resources 5.68%
# Schooling 5.55%

# %%
who.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', '% health financing', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio',
#        'Total health financing', 'Diphtheria', 'HIV/AIDS', 'GDP', 'Population',
#        'thinness  1-19 years', 'thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
#drop Total health financing, I have a column with the percentage of it already
#drop Countries and Population (Population is related)
#drop Hepatitis B (almost 20% of Nans)
#also drop Year, no need
#in the end: drop rows with Nans

# %%
who.drop(columns=['Total health financing','Country','Population','Hepatitis B','Year'], inplace=True)

# %%
who.shape #(2938, 18)
# Out:
# (2938, 17)

# %%
who_clean = who.dropna(axis=0)

# %%
who_clean.shape #2304
# Out:
# (2304, 17)

# %%
who_corr = who.corr()
heatmap = who_corr.style.background_gradient(cmap='RdYlGn',axis=None).set_precision(2)
heatmap #nice correlations
# Out:
# <style  type="text/css" >
#     #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col0 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col1 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col2 {
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col3 {
#             background-color:  #bfe47a;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col4 {
#             background-color:  #c7e77f;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col5 {
#             background-color:  #fdb768;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col6 {
#             background-color:  #89cc67;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col7 {
#             background-color:  #fba05b;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col8 {
#             background-color:  #addc6f;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col9 {
#             background-color:  #a9da6c;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col10 {
#             background-color:  #ce2827;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col11 {
#             background-color:  #afdd70;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col12 {
#             background-color:  #e0422f;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col13 {
#             background-color:  #e0422f;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col14 {
#             background-color:  #48ae5c;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row0_col15 {
#             background-color:  #3ca959;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col0 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col1 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col2 {
#             background-color:  #fff1a8;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col3 {
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col4 {
#             background-color:  #fa9857;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col5 {
#             background-color:  #fee999;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col6 {
#             background-color:  #ee613e;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col7 {
#             background-color:  #fff5ae;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col8 {
#             background-color:  #f88c51;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col9 {
#             background-color:  #f88c51;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col10 {
#             background-color:  #98d368;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col11 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col12 {
#             background-color:  #ddf191;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col13 {
#             background-color:  #dcf08f;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col14 {
#             background-color:  #e34933;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row1_col15 {
#             background-color:  #e34933;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col0 {
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col1 {
#             background-color:  #fff1a8;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col2 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col3 {
#             background-color:  #fdc372;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col4 {
#             background-color:  #fecc7b;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col5 {
#             background-color:  #a2d76a;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col6 {
#             background-color:  #fb9d59;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col7 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col8 {
#             background-color:  #fdb365;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col9 {
#             background-color:  #fdb163;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col10 {
#             background-color:  #fee797;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col11 {
#             background-color:  #fdc574;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col12 {
#             background-color:  #addc6f;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col13 {
#             background-color:  #abdb6d;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col14 {
#             background-color:  #fdbb6c;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row2_col15 {
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col0 {
#             background-color:  #bfe47a;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col1 {
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col2 {
#             background-color:  #fdc372;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col3 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col4 {
#             background-color:  #d3ec87;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col5 {
#             background-color:  #fed683;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col6 {
#             background-color:  #d7ee8a;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col7 {
#             background-color:  #fdc574;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col8 {
#             background-color:  #eff8aa;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col9 {
#             background-color:  #eff8aa;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col10 {
#             background-color:  #fed683;
#             color:  #000000;
#         }    #T_06715036_f102_11e9_9086_c8bcc89f66f8row3_col11 {
#             background-color:  #cfeb85;

# %%
who_clean.dtypes
# Out:
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# % health financing                 float64
# Measles                              int64
# BMI                                float64
# under-five deaths                    int64
# Polio                              float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# thinness  1-19 years               float64
# thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
who = pd.get_dummies(who_clean, drop_first=True)
who.Status_Developing.value_counts()
# Out:
# 1    1881
# 0     423
# Name: Status_Developing, dtype: int64

# %%
who.head()
# Out:
#    Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0             65.0            263.0             62     0.01
# 1             59.9            271.0             64     0.01
# 2             59.9            268.0             66     0.01
# 3             59.5            272.0             69     0.01
# 4             59.2            275.0             71     0.01
#
#    % health financing  Measles   BMI  under-five deaths  Polio  Diphtheria  \
# 0           71.279624     1154  19.1                 83    6.0        65.0
# 1           73.523582      492  18.6                 86   58.0        62.0
# 2           73.219243      430  18.1                 89   62.0        64.0
# 3           78.184215     2787  17.6                 93   67.0        67.0
# 4            7.097109     3013  17.2                 97   68.0        68.0
#
#    HIV/AIDS         GDP  thinness  1-19 years  thinness 5-9 years  \
# 0       0.1  584.259210                  17.2                17.3
# 1       0.1  612.696514                  17.5                17.5
# 2       0.1  631.744976                  17.7                17.7
# 3       0.1  669.959000                  17.9                18.0
# 4       0.1   63.537231                  18.2                18.2
#
#    Income composition of resources  Schooling  Status_Developing
# 0                            0.479       10.1                  1
# 1                            0.476       10.0                  1
# 2                            0.470        9.9                  1
# 3                            0.463        9.8                  1
# 4                            0.454        9.5                  1

# %%
who.dtypes
# Out:
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# % health financing                 float64
# Measles                              int64
# BMI                                float64
# under-five deaths                    int64
# Polio                              float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# thinness  1-19 years               float64
# thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# Status_Developing                    uint8
# dtype: object

# %%
who.describe()
# Out:
#        Life expectancy  Adult Mortality  infant deaths      Alcohol  \
# count      2304.000000      2304.000000    2304.000000  2304.000000
# mean         69.338455       161.506944      31.644965     4.623472
# std           9.712894       127.875825     129.477633     4.026808
# min          36.300000         1.000000       0.000000     0.010000
# 25%          63.200000        69.000000       0.000000     0.895000
# 50%          72.200000       137.000000       2.000000     3.965000
# 75%          76.000000       224.000000      19.000000     7.592500
# max          89.000000       723.000000    1800.000000    17.870000
#
#        % health financing        Measles          BMI  under-five deaths  \
# count         2304.000000    2304.000000  2304.000000        2304.000000
# mean           939.446860    2413.818576    38.097222          43.995660
# std           2202.564497   11312.768375    19.816297         176.302342
# min              0.000000       0.000000     1.400000           0.000000
# 25%             35.841481       0.000000    18.975000           0.000000
# 50%            155.315287      15.000000    43.500000           3.000000
# 75%            641.192963     353.250000    55.900000          24.000000
# max          19479.911610  212183.000000    77.100000        2500.000000
#
#              Polio   Diphtheria     HIV/AIDS            GDP  \
# count  2304.000000  2304.000000  2304.000000    2304.000000
# mean     82.679688    82.578125     1.976302    7617.916013
# std      23.096802    23.381987     5.626433   14535.338226
# min       3.000000     2.000000     0.100000       1.681350
# 25%      78.000000    79.000000     0.100000     454.891745
# 50%      93.000000    93.000000     0.100000    1759.357808
# 75%      97.000000    97.000000     0.900000    5945.671748
# max      99.000000    99.000000    50.600000  119172.741800
#
#        thinness  1-19 years  thinness 5-9 years  \
# count           2304.000000         2304.000000
# mean               4.861545            4.903125
# std                4.528618            4.621498
# min                0.100000            0.100000
# 25%                1.600000            1.600000
# 50%                3.300000            3.300000
# 75%                7.100000            7.200000
# max               27.700000           28.600000
#
#        Income composition of resources    Schooling  Status_Developing
# count                       2304.00000  2304.000000        2304.000000
# mean                           0.63099    12.126172           0.816406
# std                            0.21317     3.306716           0.387237
# min                            0.00000     0.000000           0.000000
# 25%                            0.49100    10.100000           1.000000
# 50%                            0.68300    12.400000           1.000000
# 75%                            0.78700    14.425000           1.000000
# max                            0.94800    20.700000           1.000000

# %%
#split in train and test set
y = who['Life expectancy']
X = who.drop(['Life expectancy'], axis = 1)

# Standarize features
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_std, y, test_size = 0.2, random_state=29)

# %%
regr = LinearRegression()
model = regr.fit(X_std, y)
acc = model.score(X_test,y_test)*100
print(f"Model (Linear Regression) Test Accuracy {round(acc, 2)}%")
# Out:
# Model (Linear Regression) Test Accuracy 82.19%
